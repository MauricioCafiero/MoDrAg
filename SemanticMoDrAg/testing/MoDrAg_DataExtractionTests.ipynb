# %% [markdown]
# ## Install and Import

# %%
# !pip install -q anthropic
# !pip install -q "gliner[tokenizers]"
# !pip install rdkit
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 455.2/455.2 kB 29.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 60.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 7.6 MB/s eta 0:00:00
# WARNING: Package 'camel-tools' has an invalid Requires-Python: Invalid specifier: '<3.10.*'
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 14.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.9/163.9 kB 22.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.3/40.3 kB 5.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.7/19.7 MB 119.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 9.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 130.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 579.6/579.6 kB 51.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 90.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 773.7/773.7 kB 38.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 5.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 608.4/608.4 kB 53.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.3/122.3 kB 15.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.5/34.5 MB 72.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 126.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.1/121.1 kB 14.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 337.2/337.2 kB 9.4 MB/s eta 0:00:00
#   Building wheel for langdetect (setup.py) ... done
#   Building wheel for docopt (setup.py) ... done
# Collecting rdkit
#   Downloading rdkit-2025.9.5-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (3.8 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from rdkit) (2.0.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from rdkit) (11.3.0)
# Downloading rdkit-2025.9.5-cp312-cp312-manylinux_2_28_x86_64.whl (36.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.7/36.7 MB 75.5 MB/s eta 0:00:00
# Installing collected packages: rdkit
# Successfully installed rdkit-2025.9.5

# %%
# !git clone https://github.com/MauricioCafiero/MoDrAg.git
# Out:
# Cloning into 'MoDrAg'...
# remote: Enumerating objects: 494, done.
# remote: Counting objects: 100% (267/267), done.
# remote: Compressing objects: 100% (197/197), done.
# remote: Total 494 (delta 171), reused 150 (delta 64), pack-reused 227 (from 1)
# Receiving objects: 100% (494/494), 44.74 MiB | 12.64 MiB/s, done.
# Resolving deltas: 100% (282/282), done.

# %%
import importlib, sys
importlib.reload(sys.modules['just_parse'])
importlib.reload(sys.modules['parsing_tests'])
# Out:
# <module 'parsing_tests' from '/content/MoDrAg/SemanticMoDrAg/testing/parsing_tests.py'>

# %%
import sys
sys.path.append('MoDrAg/SemanticMoDrAg/code')
sys.path.append('MoDrAg/SemanticMoDrAg/testing')
from just_parse import *
from parsing_tests import *

from transformers import pipeline
import torch
from openai import OpenAI
from anthropic import Anthropic
import os, time
from google.colab import userdata

# %% [markdown]
# ## Sample queries

# %%
queries = ['Dock paracetamol in DRD2', 'Find the Lipinski properties of rosuvastatin and [NH3+]CCc1ccc(O)cc1']

truths = [{
    'proteins_list': ['DRD2'],
      'names_list': ['paracetamol'],
      'diseases_list': [],
      'smiles_list': [],
      'uniprot_list': [],
      'pdb_list': [],
      'chembl_list': []
},
    {
    'proteins_list': [],
      'names_list': ['rosuvastatin'],
      'diseases_list': [],
      'smiles_list': ['[NH3+]CCc1ccc(O)cc1'],
      'uniprot_list': [],
      'pdb_list': [],
      'chembl_list': []
}]

# %% [markdown]
# ## Semantic and Regex
# - NER model is running on a A100 currently.
# - 0$
#
# ### Claude
# - claude-haiku-4-5-20251001
# - $1 per M input
# - \$5 per M output
#
# ### OpenAI
# - GPT 5.2
# - $1.75 per M input
# - \$14 per M output

# %%
gemma_pipe, granite_pipe, ner_model = prep_tests()
# Out:
# Loading Hugging Face model...
# config.json:   0%|          | 0.00/899 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.00G [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/340 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/215 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.16M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/33.4M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/35.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/662 [00:00<?, ?B/s]
# Loading Hugging Face model...
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/3.26G [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/322 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/579 [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# chat_template.jinja: 0.00B [00:00, ?B/s]
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_validators.py:186: UserWarning: The `resume_download` argument is deprecated and ignored in `snapshot_download`. Downloads always resume whenever possible.
#   warnings.warn(
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 10 files:   0%|          | 0/10 [00:00<?, ?it/s]

# %%
openai_key = userdata.get('OPENAI_API_KEY')
openai_client = OpenAI(api_key=openai_key)

anthropic_key = userdata.get('ANTHROPIC_KEY')
anthropic_client = Anthropic(api_key=anthropic_key)

# %%
run_tests(queries[1], truths[1], gemma_pipe, granite_pipe, openai_client, anthropic_client, ner_model)
# Out:
# Testing Caf parser...
# Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Initial SMILES matches: ['[NH3+]CCc1ccc(O)cc1']
# Modified SMILES matches: ['[NH3+]CCc1ccc(O)cc1']
# ================================================================
# names_list: ['rosuvastatin']
# smiles_list: ['[NH3+]CCc1ccc(O)cc1']
# ================================================================
# Testing Hugging Face model...
# Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# ================================================================
# smiles_list: CC(=O)Nc1ccc(O)cc1
# names_list: ['Rosuvastate']
# proteins_list: ['[NH3+]CCc1ccc(O)cc1']
# pdb_list: ['[NH3+]CCc1ccc(O)cc1']
# uniprot_list: ['[NH3+]CCc1ccc(O)cc1']
# ================================================================
# Testing Hugging Face model...
# ================================================================
# Failed to parse results
# ================================================================
# Testing ChatGPT...
# smiles_list: ['[NH3+]CCc1ccc(O)cc1']
# names_list: ['rosuvastatin']
# ================================================================
# Testing Anthropic Claude...
# smiles_list: ['[NH3+]CCc1ccc(O)cc1']
# names_list: ['rosuvastatin']
# ================================================================
# caf_parse had 2 hits and 0 misses and took 0.356 seconds
# gemma had 0 hits and 5 misses and took 8.071 seconds
# granite failed to parse results and took 0.893 seconds
# chatgpt had 2 hits and 0 misses and took 1.713 seconds
# anthropic had 2 hits and 0 misses and took 1.037 seconds

# %%
clean_and_test_results(truths[1], truths[1], 'test', 1.0)
# Out:
# names_list: ['rosuvastatin']
# smiles_list: ['[NH3+]CCc1ccc(O)cc1']
# 'test had 2 hits and 0 misses and took 1.000 seconds'
